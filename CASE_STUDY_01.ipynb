# %% [markdown]
# To load the loan prediction dataset into the Python environment.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the data

# %%
df = pd.read_csv("train_loan.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# Display first 5 records
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
# Statistical summary
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Separate numerical and categorical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

# %%
# Fill missing numerical values with median
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# /tmp/ipython-input-4235919639.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %%
# Fill missing categorical values with mode
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-2158818886.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
# Verify missing values are handled
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

# %%
# Remove outliers
df = df[~((df[num_cols] < (Q1 - 1.5 * IQR)) |
          (df[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Dataset shape after outlier removal
df.shape
# Out:
# (396, 13)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

for col in cat_cols:
    if df[col].nunique() == 2:
        df[col] = le.fit_transform(df[col])

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#    Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0              0             5849
# 1       1        1          0              0             4583
# 2       1        1          0              1             3000
# 3       1        1          1              0             2583
# 4       1        0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Loan_Status  ...  Loan_ID_LP002964  Loan_ID_LP002974  Loan_ID_LP002978  \
# 0            1  ...             False             False             False
# 1            0  ...             False             False             False
# 2            1  ...             False             False             False
# 3            1  ...             False             False             False
# 4            1  ...             False             False             False
#
#    Loan_ID_LP002983  Loan_ID_LP002984  Dependents_1  Dependents_2  \
# 0             False             False         False         False
# 1             False             False          True         False
# 2             False             False         False         False
# 3             False             False         False         False
# 4             False             False         False         False
#
#    Dependents_3+  Property_Area_Semiurban  Property_Area_Urban
# 0          False                    False                 True
# 1          False                    False                False
# 2          False                    False                 True
# 3          False                    False                 True
# 4          False                    False                 True
#
# [5 rows x 410 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df.head()
# Out:
#    Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0              0         0.960029
# 1       1        1          0              0         0.280905
# 2       1        1          0              1        -0.568268
# 3       1        1          1              0        -0.791960
# 4       1        0          0              0         1.041031
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.953550   -0.010551               0.0             0.0
# 1           0.109487   -0.010551               0.0             0.0
# 2          -0.953550   -1.388519               0.0             0.0
# 3           0.708679   -0.188354               0.0             0.0
# 4          -0.953550    0.278377               0.0             0.0
#
#    Loan_Status  ...  Loan_ID_LP002964  Loan_ID_LP002974  Loan_ID_LP002978  \
# 0            1  ...             False             False             False
# 1            0  ...             False             False             False
# 2            1  ...             False             False             False
# 3            1  ...             False             False             False
# 4            1  ...             False             False             False
#
#    Loan_ID_LP002983  Loan_ID_LP002984  Dependents_1  Dependents_2  \
# 0             False             False         False         False
# 1             False             False          True         False
# 2             False             False         False         False
# 3             False             False         False         False
# 4             False             False         False         False
#
#    Dependents_3+  Property_Area_Semiurban  Property_Area_Urban
# 0          False                    False                 True
# 1          False                    False                False
# 2          False                    False                 True
# 3          False                    False                 True
# 4          False                    False                 True
#
# [5 rows x 410 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 396 entries, 0 to 612
# Columns: 410 entries, Gender to Property_Area_Urban
# dtypes: bool(400), float64(5), int64(5)
# memory usage: 188.7 KB

# %%
df.describe()
# Out:
#            Gender     Married   Education  Self_Employed  ApplicantIncome  \
# count  396.000000  396.000000  396.000000     396.000000     3.960000e+02
# mean     0.808081    0.643939    0.217172       0.116162    -1.009294e-16
# std      0.394308    0.479439    0.412842       0.320824     1.001265e+00
# min      0.000000    0.000000    0.000000       0.000000    -2.097102e+00
# 25%      1.000000    0.000000    0.000000       0.000000    -7.208831e-01
# 50%      1.000000    1.000000    0.000000       0.000000    -2.163680e-01
# 75%      1.000000    1.000000    0.000000       0.000000     4.431762e-01
# max      1.000000    1.000000    1.000000       1.000000     3.261326e+00
#
#        CoapplicantIncome    LoanAmount  Loan_Amount_Term  Credit_History  \
# count       3.960000e+02  3.960000e+02             396.0           396.0
# mean        2.242875e-17 -2.915737e-16               0.0             0.0
# std         1.001265e+00  1.001265e+00               0.0             0.0
# min        -9.535502e-01 -2.655361e+00               0.0             0.0
# 25%        -9.535502e-01 -6.328595e-01               0.0             0.0
# 50%        -9.646740e-03 -4.388933e-02               0.0             0.0
# 75%         6.150989e-01  5.895314e-01               0.0             0.0
# max         3.011690e+00  2.923187e+00               0.0             0.0
#
#        Loan_Status
# count   396.000000
# mean      0.813131
# std       0.390299
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
